# %%
import math
import csv
def load_csv(filename):
        lines = csv.reader(open(filename, "r"));
        dataset = list(lines)
        headers = dataset.pop(0)
        return dataset, headers

# %%
class Node:
    def __init__(self, attribute):
        self.attribute = attribute
        print("self.attribute")
        print(self.attribute)
        self.children = []
        print(self.children)
        self.answer = ""

# %%
def subtables(data, col, delete):
    dic = {}
    coldata = [ row[col] for row in data]
    attr = list(set(coldata))
    print("attr")
    print(attr)
    for k in attr:
        dic[k] = []
        print(dic[k])    
    for y in range(len(data)):
        key = data[y][col]
        print(key)
        if delete:
            del data[y][col]
        dic[key].append(data[y])
        print(dic) 

    return attr, dic

# %%
def entropy(S):
    print("entropy")  
    attr = list(set(S))
    print(attr)
    if len(attr) == 1: 
        return 0
    counts = [0,0] 
    for i in range(2):
        counts[i] = sum( [1 for x in S if attr[i] == x] ) / (len(S) * 1.0)
        print(counts[i])
    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)
    return sums

# %%
def compute_gain(data, col):

    attValues, dic = subtables(data, col, delete=False)
    print(attValues)
    print(dic)
    print([row[-1] for row in data])
    total_entropy = entropy([row[-1] for row in data])
    print("out total_entropy")
    print(total_entropy)
    for x in range(len(attValues)):

        ratio = len(dic[attValues[x]]) / ( len(data) * 1.0) 
        print("ratio")
        print(ratio)
        entro = entropy([row[-1] for row in dic[attValues[x]]]) 
        print(entro) 
        total_entropy -= ratio*entro
        print("in total_entropy")
        print(total_entropy)
    return total_entropy

# %%
def build_tree(data, features):
    
    lastcol = [row[-1] for row in data]
    
    print(lastcol)
    
    print(len(set(lastcol)))

    print("hi")
    
    if (len(set(lastcol))) == 1: 
        node=Node("")
        print(node.attribute)
        print(node.children)
        node.answer = lastcol[0]
        print("hello")
        return node

    print(data[0])
    n = len(data[0])-1
    print(n)
    
    gains = [compute_gain(data, col) for col in range(n) ]
    print("GAINS")
    print(gains)
    

    split = gains.index(max(gains)) 
    print(split)
    node = Node(features[split]) 
    print("node")
    print(node)
    fea = features[:split]+features[split+1:]
    print("fea")
    print(fea)
    attr, dic = subtables(data, split, delete=True) 
    
    print(attr) 
    print(dic)
    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)

        node.children.append((attr[x], child))

    return node

# %%
def print_tree(node, level):

    if node.answer != "":

        print(" "*level, node.answer) 
        return
    print(" "*level, node.attribute)  
    for value, n in node.children:
        print("	"*(level+1), value)
        print_tree(n, level + 2)

# %%
def classify(node,x_test,features):

    if node.answer != "":  
        print(node.answer)

        return

    pos = features.index(node.attribute)
    print(pos)

    for value, n in node.children:

        if x_test[pos]==value:

            classify(n,x_test,features)

''' Main program '''

dataset, features = load_csv("tennis.csv")  
node = build_tree(dataset, features) 

print("The decision tree for the dataset using ID3 algorithm is ")

print_tree(node, 0)

testdata, features = load_csv("tennis.csv")

for xtest in testdata:

    print("The test instance : ",xtest)
    print("The predicted label : ",end="")
    classify(node,xtest,features)
# Out:
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# 2
# hi
# ['Sunny', 'Hot', 'High', 'weak', 'No']
# 4
# attr
# ['Sunny', 'Rainy', 'Overcast']
# []
# []
# []
# Sunny
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No']], 'Rainy': [], 'Overcast': []}
# Sunny
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [], 'Overcast': []}
# Overcast
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# Overcast
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Rainy
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Overcast
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']]}
# Overcast
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# ['Sunny', 'Rainy', 'Overcast']
# {'Sunny': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'Overcast': [['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.35714285714285715
# 0.6428571428571429
# out total_entropy
# 0.9402859586706309
# ratio
# 0.35714285714285715
# entropy
# ['No', 'Yes']
# 0.6
# 0.4
# 0.9709505944546686
# in total_entropy
# 0.593517889222535
# ratio
# 0.35714285714285715
# entropy
# ['No', 'Yes']
# 0.4
# 0.6
# 0.9709505944546686
# in total_entropy
# 0.2467498197744391
# ratio
# 0.2857142857142857
# entropy
# ['Yes']
# 0
# in total_entropy
# 0.2467498197744391
# attr
# ['Mild', 'Hot', 'Cool']
# []
# []
# []
# Hot
# {'Mild': [], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No']], 'Cool': []}
# Hot
# {'Mild': [], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']], 'Cool': []}
# Hot
# {'Mild': [], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': []}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': []}
# Cool
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes']]}
# Cool
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']]}
# Cool
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']]}
# Cool
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# Hot
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# Mild
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# ['Mild', 'Hot', 'Cool']
# {'Mild': [['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'Hot': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'Cool': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.35714285714285715
# 0.6428571428571429
# out total_entropy
# 0.9402859586706309
# ratio
# 0.42857142857142855
# entropy
# ['No', 'Yes']
# 0.3333333333333333
# 0.6666666666666666
# 0.9182958340544896
# in total_entropy
# 0.5467306012187069
# ratio
# 0.2857142857142857
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.26101631550442117
# ratio
# 0.2857142857142857
# entropy
# ['No', 'Yes']
# 0.25
# 0.75
# 0.8112781244591328
# in total_entropy
# 0.029222565658954647
# attr
# ['Normal', 'High']
# []
# []
# High
# {'Normal': [], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No']]}
# High
# {'Normal': [], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No']]}
# High
# {'Normal': [], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# High
# {'Normal': [], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes']]}
# High
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']]}
# High
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']]}
# Normal
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']]}
# High
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']]}
# ['Normal', 'High']
# {'Normal': [['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']], 'High': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Sunny', 'Hot', 'High', 'strong', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']]}
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.35714285714285715
# 0.6428571428571429
# out total_entropy
# 0.9402859586706309
# ratio
# 0.5
# entropy
# ['No', 'Yes']
# 0.14285714285714285
# 0.8571428571428571
# 0.5916727785823275
# in total_entropy
# 0.6444495693794672
# ratio
# 0.5
# entropy
# ['No', 'Yes']
# 0.5714285714285714
# 0.42857142857142855
# 0.9852281360342516
# in total_entropy
# 0.15183550136234136
# attr
# ['strong', 'weak']
# []
# []
# weak
# {'strong': [], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']]}
# weak
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# ['strong', 'weak']
# {'strong': [['Sunny', 'Hot', 'High', 'strong', 'No'], ['Rainy', 'Cool', 'Normal', 'strong', 'No'], ['Overcast', 'Cool', 'Normal', 'strong', 'Yes'], ['Sunny', 'Mild', 'Normal', 'strong', 'Yes'], ['Overcast', 'Mild', 'High', 'strong', 'Yes'], ['Rainy', 'Mild', 'High', 'strong', 'No']], 'weak': [['Sunny', 'Hot', 'High', 'weak', 'No'], ['Overcast', 'Hot', 'High', 'weak', 'Yes'], ['Rainy', 'Mild', 'High', 'weak', 'Yes'], ['Rainy', 'Cool', 'Normal', 'weak', 'Yes'], ['Sunny', 'Mild', 'High', 'weak', 'No'], ['Sunny', 'Cool', 'Normal', 'weak', 'Yes'], ['Rainy', 'Mild', 'Normal', 'weak', 'Yes'], ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.35714285714285715
# 0.6428571428571429
# out total_entropy
# 0.9402859586706309
# ratio
# 0.42857142857142855
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.5117145300992023
# ratio
# 0.5714285714285714
# entropy
# ['No', 'Yes']
# 0.25
# 0.75
# 0.8112781244591328
# in total_entropy
# 0.04812703040826927
# GAINS
# [0.2467498197744391, 0.029222565658954647, 0.15183550136234136, 0.04812703040826927]
# 0
# self.attribute
# Outlook
# []
# node
# <__main__.Node object at 0x000001D4833E5358>
# fea
# ['Temperature', 'Humidity', 'Windy', 'PlayTennis']
# attr
# ['Sunny', 'Rainy', 'Overcast']
# []
# []
# []
# Sunny
# {'Sunny': [['Hot', 'High', 'weak', 'No']], 'Rainy': [], 'Overcast': []}
# Sunny
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [], 'Overcast': []}
# Overcast
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [], 'Overcast': [['Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [['Mild', 'High', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes']]}
# Overcast
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes']]}
# Rainy
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes']]}
# Sunny
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes']]}
# Overcast
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes'], ['Mild', 'High', 'strong', 'Yes']]}
# Overcast
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes'], ['Mild', 'High', 'strong', 'Yes'], ['Hot', 'Normal', 'weak', 'Yes']]}
# Rainy
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes'], ['Mild', 'High', 'strong', 'Yes'], ['Hot', 'Normal', 'weak', 'Yes']]}
# ['Sunny', 'Rainy', 'Overcast']
# {'Sunny': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'Rainy': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']], 'Overcast': [['Hot', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'Yes'], ['Mild', 'High', 'strong', 'Yes'], ['Hot', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'No', 'Yes', 'Yes']
# 2
# hi
# ['Hot', 'High', 'weak', 'No']
# 3
# attr
# ['Mild', 'Hot', 'Cool']
# []
# []
# []
# Hot
# {'Mild': [], 'Hot': [['Hot', 'High', 'weak', 'No']], 'Cool': []}
# Hot
# {'Mild': [], 'Hot': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Cool': []}
# Mild
# {'Mild': [['Mild', 'High', 'weak', 'No']], 'Hot': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Cool': []}
# Cool
# {'Mild': [['Mild', 'High', 'weak', 'No']], 'Hot': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes']]}
# Mild
# {'Mild': [['Mild', 'High', 'weak', 'No'], ['Mild', 'Normal', 'strong', 'Yes']], 'Hot': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes']]}
# ['Mild', 'Hot', 'Cool']
# {'Mild': [['Mild', 'High', 'weak', 'No'], ['Mild', 'Normal', 'strong', 'Yes']], 'Hot': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'No', 'Yes', 'Yes']
# entropy
# ['No', 'Yes']
# 0.6
# 0.4
# out total_entropy
# 0.9709505944546686
# ratio
# 0.4
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.5709505944546686
# ratio
# 0.4
# entropy
# ['No']
# 0
# in total_entropy
# 0.5709505944546686
# ratio
# 0.2
# entropy
# ['Yes']
# 0
# in total_entropy
# 0.5709505944546686
# attr
# ['Normal', 'High']
# []
# []
# High
# {'Normal': [], 'High': [['Hot', 'High', 'weak', 'No']]}
# High
# {'Normal': [], 'High': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No']]}
# High
# {'Normal': [], 'High': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No']]}
# Normal
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes']], 'High': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No']]}
# Normal
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'High': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No']]}
# ['Normal', 'High']
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'strong', 'Yes']], 'High': [['Hot', 'High', 'weak', 'No'], ['Hot', 'High', 'strong', 'No'], ['Mild', 'High', 'weak', 'No']]}
# ['No', 'No', 'No', 'Yes', 'Yes']
# entropy
# ['No', 'Yes']
# 0.6
# 0.4
# out total_entropy
# 0.9709505944546686
# ratio
# 0.4
# entropy
# ['Yes']
# 0
# in total_entropy
# 0.9709505944546686
# ratio
# 0.6
# entropy
# ['No']
# 0
# in total_entropy
# 0.9709505944546686
# attr
# ['strong', 'weak']
# []
# []
# weak
# {'strong': [], 'weak': [['Hot', 'High', 'weak', 'No']]}
# strong
# {'strong': [['Hot', 'High', 'strong', 'No']], 'weak': [['Hot', 'High', 'weak', 'No']]}
# weak
# {'strong': [['Hot', 'High', 'strong', 'No']], 'weak': [['Hot', 'High', 'weak', 'No'], ['Mild', 'High', 'weak', 'No']]}
# weak
# {'strong': [['Hot', 'High', 'strong', 'No']], 'weak': [['Hot', 'High', 'weak', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Hot', 'High', 'strong', 'No'], ['Mild', 'Normal', 'strong', 'Yes']], 'weak': [['Hot', 'High', 'weak', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes']]}
# ['strong', 'weak']
# {'strong': [['Hot', 'High', 'strong', 'No'], ['Mild', 'Normal', 'strong', 'Yes']], 'weak': [['Hot', 'High', 'weak', 'No'], ['Mild', 'High', 'weak', 'No'], ['Cool', 'Normal', 'weak', 'Yes']]}
# ['No', 'No', 'No', 'Yes', 'Yes']
# entropy
# ['No', 'Yes']
# 0.6
# 0.4
# out total_entropy
# 0.9709505944546686
# ratio
# 0.4
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.5709505944546686
# ratio
# 0.6
# entropy
# ['No', 'Yes']
# 0.6666666666666666
# 0.3333333333333333
# 0.9182958340544896
# in total_entropy
# 0.01997309402197489
# GAINS
# [0.5709505944546686, 0.9709505944546686, 0.01997309402197489]
# 1
# self.attribute
# Humidity
# []
# node
# <__main__.Node object at 0x000001D4833DB198>
# fea
# ['Temperature', 'Windy', 'PlayTennis']
# attr
# ['Normal', 'High']
# []
# []
# High
# {'Normal': [], 'High': [['Hot', 'weak', 'No']]}
# High
# {'Normal': [], 'High': [['Hot', 'weak', 'No'], ['Hot', 'strong', 'No']]}
# High
# {'Normal': [], 'High': [['Hot', 'weak', 'No'], ['Hot', 'strong', 'No'], ['Mild', 'weak', 'No']]}
# Normal
# {'Normal': [['Cool', 'weak', 'Yes']], 'High': [['Hot', 'weak', 'No'], ['Hot', 'strong', 'No'], ['Mild', 'weak', 'No']]}
# Normal
# {'Normal': [['Cool', 'weak', 'Yes'], ['Mild', 'strong', 'Yes']], 'High': [['Hot', 'weak', 'No'], ['Hot', 'strong', 'No'], ['Mild', 'weak', 'No']]}
# ['Normal', 'High']
# {'Normal': [['Cool', 'weak', 'Yes'], ['Mild', 'strong', 'Yes']], 'High': [['Hot', 'weak', 'No'], ['Hot', 'strong', 'No'], ['Mild', 'weak', 'No']]}
# ['Yes', 'Yes']
# 1
# hi
# self.attribute
#
# []
#
# []
# hello
# ['No', 'No', 'No']
# 1
# hi
# self.attribute
#
# []
#
# []
# hello
# ['Yes', 'Yes', 'No', 'Yes', 'No']
# 2
# hi
# ['Mild', 'High', 'weak', 'Yes']
# 3
# attr
# ['Mild', 'Cool']
# []
# []
# Mild
# {'Mild': [['Mild', 'High', 'weak', 'Yes']], 'Cool': []}
# Cool
# {'Mild': [['Mild', 'High', 'weak', 'Yes']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes']]}
# Cool
# {'Mild': [['Mild', 'High', 'weak', 'Yes']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']]}
# Mild
# {'Mild': [['Mild', 'High', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']]}
# Mild
# {'Mild': [['Mild', 'High', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']]}
# ['Mild', 'Cool']
# {'Mild': [['Mild', 'High', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']], 'Cool': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']]}
# ['Yes', 'Yes', 'No', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.4
# 0.6
# out total_entropy
# 0.9709505944546686
# ratio
# 0.6
# entropy
# ['No', 'Yes']
# 0.3333333333333333
# 0.6666666666666666
# 0.9182958340544896
# in total_entropy
# 0.4199730940219749
# ratio
# 0.4
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.01997309402197489
# attr
# ['Normal', 'High']
# []
# []
# High
# {'Normal': [], 'High': [['Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes']], 'High': [['Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No']], 'High': [['Mild', 'High', 'weak', 'Yes']]}
# Normal
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'High': [['Mild', 'High', 'weak', 'Yes']]}
# High
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'High': [['Mild', 'High', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']]}
# ['Normal', 'High']
# {'Normal': [['Cool', 'Normal', 'weak', 'Yes'], ['Cool', 'Normal', 'strong', 'No'], ['Mild', 'Normal', 'weak', 'Yes']], 'High': [['Mild', 'High', 'weak', 'Yes'], ['Mild', 'High', 'strong', 'No']]}
# ['Yes', 'Yes', 'No', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.4
# 0.6
# out total_entropy
# 0.9709505944546686
# ratio
# 0.6
# entropy
# ['No', 'Yes']
# 0.3333333333333333
# 0.6666666666666666
# 0.9182958340544896
# in total_entropy
# 0.4199730940219749
# ratio
# 0.4
# entropy
# ['No', 'Yes']
# 0.5
# 0.5
# 1.0
# in total_entropy
# 0.01997309402197489
# attr
# ['strong', 'weak']
# []
# []
# weak
# {'strong': [], 'weak': [['Mild', 'High', 'weak', 'Yes']]}
# weak
# {'strong': [], 'weak': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Cool', 'Normal', 'strong', 'No']], 'weak': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes']]}
# weak
# {'strong': [['Cool', 'Normal', 'strong', 'No']], 'weak': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes']]}
# strong
# {'strong': [['Cool', 'Normal', 'strong', 'No'], ['Mild', 'High', 'strong', 'No']], 'weak': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes']]}
# ['strong', 'weak']
# {'strong': [['Cool', 'Normal', 'strong', 'No'], ['Mild', 'High', 'strong', 'No']], 'weak': [['Mild', 'High', 'weak', 'Yes'], ['Cool', 'Normal', 'weak', 'Yes'], ['Mild', 'Normal', 'weak', 'Yes']]}
# ['Yes', 'Yes', 'No', 'Yes', 'No']
# entropy
# ['No', 'Yes']
# 0.4
# 0.6
# out total_entropy
# 0.9709505944546686
# ratio
# 0.4
# entropy
# ['No']
# 0
# in total_entropy
# 0.9709505944546686
# ratio
# 0.6
# entropy
# ['Yes']
# 0
# in total_entropy
# 0.9709505944546686
# GAINS
# [0.01997309402197489, 0.01997309402197489, 0.9709505944546686]
# 2
# self.attribute
# Windy
# []
# node
# <__main__.Node object at 0x000001D4833DBAC8>
# fea
# ['Temperature', 'Humidity', 'PlayTennis']
# attr
# ['strong', 'weak']
# []
# []
# weak
# {'strong': [], 'weak': [['Mild', 'High', 'Yes']]}
# weak
# {'strong': [], 'weak': [['Mild', 'High', 'Yes'], ['Cool', 'Normal', 'Yes']]}
# strong
# {'strong': [['Cool', 'Normal', 'No']], 'weak': [['Mild', 'High', 'Yes'], ['Cool', 'Normal', 'Yes']]}
# weak
# {'strong': [['Cool', 'Normal', 'No']], 'weak': [['Mild', 'High', 'Yes'], ['Cool', 'Normal', 'Yes'], ['Mild', 'Normal', 'Yes']]}
# strong
# {'strong': [['Cool', 'Normal', 'No'], ['Mild', 'High', 'No']], 'weak': [['Mild', 'High', 'Yes'], ['Cool', 'Normal', 'Yes'], ['Mild', 'Normal', 'Yes']]}
# ['strong', 'weak']
# {'strong': [['Cool', 'Normal', 'No'], ['Mild', 'High', 'No']], 'weak': [['Mild', 'High', 'Yes'], ['Cool', 'Normal', 'Yes'], ['Mild', 'Normal', 'Yes']]}
# ['No', 'No']
# 1
# hi
# self.attribute
#
# []
#
# []
# hello
# ['Yes', 'Yes', 'Yes']
# 1
# hi
# self.attribute
#
# []
#
# []
# hello
# ['Yes', 'Yes', 'Yes', 'Yes']
# 1
# hi
# self.attribute
#
# []
#
# []
# hello
# The decision tree for the dataset using ID3 algorithm is
#  Outlook
# 	 Sunny
#    Humidity
# 			 Normal
#      Yes
# 			 High
#      No
# 	 Rainy
#    Windy
# 			 strong
#      No
# 			 weak
#      Yes
# 	 Overcast
#    Yes
# The test instance :  ['Sunny', 'Hot', 'High', 'weak', 'No']
# The predicted label : 0
# 2
# No
# The test instance :  ['Sunny', 'Hot', 'High', 'strong', 'No']
# The predicted label : 0
# 2
# No
# The test instance :  ['Overcast', 'Hot', 'High', 'weak', 'Yes']
# The predicted label : 0
# Yes
# The test instance :  ['Rainy', 'Mild', 'High', 'weak', 'Yes']
# The predicted label : 0
# 3
# Yes
# The test instance :  ['Rainy', 'Cool', 'Normal', 'weak', 'Yes']
# The predicted label : 0
# 3
# Yes
# The test instance :  ['Rainy', 'Cool', 'Normal', 'strong', 'No']
# The predicted label : 0
# 3
# No
# The test instance :  ['Overcast', 'Cool', 'Normal', 'strong', 'Yes']
# The predicted label : 0
# Yes
# The test instance :  ['Sunny', 'Mild', 'High', 'weak', 'No']
# The predicted label : 0
# 2
# No
# The test instance :  ['Sunny', 'Cool', 'Normal', 'weak', 'Yes']
# The predicted label : 0
# 2
# Yes
# The test instance :  ['Rainy', 'Mild', 'Normal', 'weak', 'Yes']
# The predicted label : 0
# 3
# Yes
# The test instance :  ['Sunny', 'Mild', 'Normal', 'strong', 'Yes']
# The predicted label : 0
# 2
# Yes
# The test instance :  ['Overcast', 'Mild', 'High', 'strong', 'Yes']
# The predicted label : 0
# Yes
# The test instance :  ['Overcast', 'Hot', 'Normal', 'weak', 'Yes']
# The predicted label : 0
# Yes
# The test instance :  ['Rainy', 'Mild', 'High', 'strong', 'No']
# The predicted label : 0
# 3
# No
